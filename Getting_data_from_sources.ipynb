# %% [markdown]
# <a href="https://colab.research.google.com/github/Bageshri123/Bageshri-Portfolio/blob/main/Getting_data_from_sources.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Skills Covered**
#
# Getting data from a range of sources

# %% [markdown]
# **Exercise:Upload a CSV file to your own Github account and write Python code to load it into a dataframe.**

# %% [markdown]
# 1.   I downloaded the CSV file from given link and saved it in a folder called 'Data Sets' on my laptop.
# 2.In my GIthub repository, I clicked on 'Add File' and then 'Upload Files'. I dragged the 'Data sets' folder stored on laptop and dropped in the repository and clicked on 'Commit Changes' to save the folder there.
# 3.I then opened the Data Sets folder in my Github repository. Then clicked to select the file housing_in_london_yearly_variables.csv.
# 4.Clicked on the 'raw' and copied the url for the raw version of dataset.
# 5. I have used this url in the below code in order create a dataframe from this csv file.

# %%
import pandas as pd
url="https://raw.githubusercontent.com/Bageshri123/Data-Science---Python/main/Data%20Sets/housing_in_london_yearly_variables.csv"
df=pd.read_csv(url)
df
# Out:
#            code                  area  ... no_of_houses  borough_flag
# 0     E09000001        city of london  ...          NaN             1
# 1     E09000002  barking and dagenham  ...          NaN             1
# 2     E09000003                barnet  ...          NaN             1
# 3     E09000004                bexley  ...          NaN             1
# 4     E09000005                 brent  ...          NaN             1
# ...         ...                   ...  ...          ...           ...
# 1066  K03000001         great britain  ...          NaN             0
# 1067  K04000001     england and wales  ...          NaN             0
# 1068  N92000002      northern ireland  ...          NaN             0
# 1069  S92000003              scotland  ...          NaN             0
# 1070  W92000004                 wales  ...          NaN             0
#
# [1071 rows x 12 columns]

# %% [markdown]
# Retrieving data from a web page

# %%
import pandas as pd
datatables = pd.read_html('https://en.wikipedia.org/wiki/Glasgow#Climate')
print("No of tables in the list:",len(datatables))
df = datatables[1]  #Glasgow population data
df
# Out:
# No of tables in the list: 25
#   The coat of arms of the City of Glasgow          The coat of arms of the City of Glasgow.1
# 0                                     NaN                                                NaN
# 1                                 Adopted                                               1866
# 2                                   Crest                                        Saint Mungo
# 3                              Supporters                          Two salmon, bearing rings
# 4                                   Motto  Let Glasgow Flourish by the preaching of Your ...

# %% [markdown]
# Getting data from a csv file hosted on Github.com

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/futureCodersSE/working-with-data/main/Data%20sets/Paisley-Weather-Data.csv"
df = pd.read_csv(url)
df
# Out:
#      yyyy  mm tmax (degC)  ... rain (mm) sun (hours)       status
# 0    1959   1           4  ...      40.9        54.1          NaN
# 1    1959   2         6.6  ...      41.8        17.8          NaN
# 2    1959   3        10.6  ...      50.9        85.7          NaN
# 3    1959   4          13  ...      76.3       125.1          NaN
# 4    1959   5        18.1  ...        24         222          NaN
# ..    ...  ..         ...  ...       ...         ...          ...
# 741  2020  10       12.9*  ...    185.3*       76.8*  Provisional
# 742  2020  11       10.6*  ...    142.4*       29.3*  Provisional
# 743  2020  12        6.9*  ...    131.0*       31.6*  Provisional
# 744  2021   1        4.9*  ...    132.2*       51.0*  Provisional
# 745  2021   2        7.0*  ...    144.3*       58.8*  Provisional
#
# [746 rows x 8 columns]

# %% [markdown]
# Getting data from an Excel file hosted on Github.com

# %%
import pandas as pd
url = "https://github.com/futureCodersSE/working-with-data/blob/main/Data%20sets/public_use-talent-migration.xlsx?raw=true"
df = pd.read_excel(url,sheet_name="Industry Migration")
df
# Out:
#      country_code          country_name  ... net_per_10K_2018 net_per_10K_2019
# 0              ae  United Arab Emirates  ...            68.51            49.55
# 1              ae  United Arab Emirates  ...           149.57           182.22
# 2              ae  United Arab Emirates  ...           409.18           407.41
# 3              ae  United Arab Emirates  ...           236.69           188.07
# 4              ae  United Arab Emirates  ...           852.39           519.40
# ...           ...                   ...  ...              ...              ...
# 5290           zw              Zimbabwe  ...            70.60           -18.30
# 5291           zw              Zimbabwe  ...          -234.59          -304.36
# 5292           zw              Zimbabwe  ...           311.03           -55.88
# 5293           zw              Zimbabwe  ...          -108.16          -213.82
# 5294           zw              Zimbabwe  ...           -39.32           -92.51
#
# ...

# %% [markdown]
# Getting data from an API which delivers the data in JSON format

# %%
import pandas as pd
import requests

url = "https://api.carbonintensity.org.uk/regional"
json_data = requests.get(url).json()['data']
print(json_data)
data_table = json_data[0]
print("\n",data_table)
df = pd.json_normalize(data_table['regions'])
df
# Out:
# [{'from': '2021-06-21T20:00Z', 'to': '2021-06-21T20:30Z', 'regions': [{'regionid': 1, 'dnoregion': 'Scottish Hydro Electric Power Distribution', 'shortname': 'North Scotland', 'intensity': {'forecast': 0, 'index': 'very low'}, 'generationmix': [{'fuel': 'biomass', 'perc': 0}, {'fuel': 'coal', 'perc': 0}, {'fuel': 'imports', 'perc': 0}, {'fuel': 'gas', 'perc': 0}, {'fuel': 'nuclear', 'perc': 0.1}, {'fuel': 'other', 'perc': 0}, {'fuel': 'hydro', 'perc': 14.7}, {'fuel': 'solar', 'perc': 0}, {'fuel': 'wind', 'perc': 85.2}]}, {'regionid': 2, 'dnoregion': 'SP Distribution', 'shortname': 'South Scotland', 'intensity': {'forecast': 30, 'index': 'very low'}, 'generationmix': [{'fuel': 'biomass', 'perc': 4.2}, {'fuel': 'coal', 'perc': 0}, {'fuel': 'imports', 'perc': 0}, {'fuel': 'gas', 'perc': 6.2}, {'fuel': 'nuclear', 'perc': 70.9}, {'fuel': 'other', 'perc': 0}, {'fuel': 'hydro', 'perc': 0.3}, {'fuel': 'solar', 'perc': 0.3}, {'fuel': 'wind', 'perc': 18.1}]}, {'regionid': 3, 'dnoregion': 'Elec
# ...
